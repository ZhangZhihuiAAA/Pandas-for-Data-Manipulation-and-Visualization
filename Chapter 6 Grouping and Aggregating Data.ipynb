# %%
import pandas as pd
import numpy as np

pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ## Groupby Using Split-Apply-Combine

# %% [markdown]
# ### Step 1: Splitting the Data
# ### Step 2: Applying a Function
# ### Step 3: Combining the Results

# %%
df = pd.read_csv('imdb.csv')
df.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama          9.3
# 1             The Godfather          1972      175   Crime          9.2
# 2           The Dark Knight          2008      152  Action          9.0
# 3    The Godfather: Part II          1974      202   Crime          9.0
# 4              12 Angry Men          1957       96   Crime          9.0
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110   28341469.0       80.0
# 1  Francis Ford Coppola   Marlon Brando      1620367  134966411.0      100.0
# 2     Christopher Nolan  Christian Bale      2303232  534858444.0       84.0
# 3  Francis Ford Coppola       Al Pacino      1129952   57300000.0       90.0
# 4          Sidney Lumet     Henry Fonda       689845    4360000.0       96.0

# %%
grouped_by_genre = df.groupby('Genre')
grouped_by_genre

# %%
for genre, group in grouped_by_genre:
    print(f'Genre: {genre}')
    print(group[['Series_Title', 'IMDB_Rating']].head())
    print()
# Out:
# Genre: Action
#                                          Series_Title  IMDB_Rating
# 2                                     The Dark Knight          9.0
# 5       The Lord of the Rings: The Return of the King          8.9
# 8                                           Inception          8.8
# 10  The Lord of the Rings: The Fellowship of the Ring          8.8
# 13              The Lord of the Rings: The Two Towers          8.7
#
# Genre: Adventure
#               Series_Title  IMDB_Rating
# 21            Interstellar          8.6
# 47      Back to the Future          8.5
# 93    Inglourious Basterds          8.3
# 110               Das Boot          8.3
# 114  2001: A Space Odyssey          8.3
#
# Genre: Animation
#                          Series_Title  IMDB_Rating
# 23      Sen to Chihiro no kamikakushi          8.6
# 43                      The Lion King          8.5
# 46                     Hotaru no haka          8.5
# 56                     Kimi no na wa.          8.4
# 58  Spider-Man: Into the Spider-Verse          8.4
#
# Genre: Biography
#         Series_Title  IMDB_Rating
# 7   Schindler's List          8.9
# 15        Goodfellas          8.7
# 18          Hamilton          8.6
# 35  The Intouchables          8.5
# 38       The Pianist          8.5
#
# Genre: Comedy
#        Series_Title  IMDB_Rating
# 19     Gisaengchung          8.6
# 26  La vita è bella          8.6
# 51     Modern Times          8.5
# 52      City Lights          8.5
# 64         3 Idiots          8.4
#
# Genre: Crime
#               Series_Title  IMDB_Rating
# 1            The Godfather          9.2
# 3   The Godfather: Part II          9.0
# 4             12 Angry Men          9.0
# 6             Pulp Fiction          8.9
# 22          Cidade de Deus          8.6
#
# Genre: Drama
#                        Series_Title  IMDB_Rating
# 0          The Shawshank Redemption          9.3
# 9                        Fight Club          8.8
# 11                     Forrest Gump          8.8
# 17  One Flew Over the Cuckoo's Nest          8.7
# 20                  Soorarai Pottru          8.6
#
# Genre: Family
#                             Series_Title  IMDB_Rating
# 688           E.T. the Extra-Terrestrial          7.8
# 698  Willy Wonka & the Chocolate Factory          7.8
#
# Genre: Fantasy
#                      Series_Title  IMDB_Rating
# 321  Das Cabinet des Dr. Caligari          8.1
# 568                     Nosferatu          7.9
#
# Genre: Film-Noir
#            Series_Title  IMDB_Rating
# 309       The Third Man          8.1
# 456  The Maltese Falcon          8.0
# 712   Shadow of a Doubt          7.8
#
# Genre: Horror
#                  Series_Title  IMDB_Rating
# 49                     Psycho          8.5
# 75                      Alien          8.4
# 271                 The Thing          8.1
# 419              The Exorcist          8.0
# 544  Night of the Living Dead          7.9
#
# Genre: Mystery
#        Series_Title  IMDB_Rating
# 69          Memento          8.4
# 81      Rear Window          8.4
# 119         Vertigo          8.3
# 145  Shutter Island          8.2
# 220         Kahaani          8.1
#
# Genre: Thriller
#         Series_Title  IMDB_Rating
# 700  Wait Until Dark          7.8
#
# Genre: Western
#                         Series_Title  IMDB_Rating
# 12   Il buono, il brutto, il cattivo          8.8
# 48      Once Upon a Time in the West          8.5
# 115       Per qualche dollaro in più          8.3
# 691           The Outlaw Josey Wales          7.8

# %%
grouped_by_director = df.groupby('Director')

type(grouped_by_director)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
movie_count_by_director = grouped_by_director.size()
movie_count_by_director
# Out:
# Director
# Aamir Khan             1
# Aaron Sorkin           1
# Abdellatif Kechiche    1
# Abhishek Chaubey       1
# Abhishek Kapoor        1
#                       ..
# Zack Snyder            2
# Zaza Urushadze         1
# Zoya Akhtar            2
# Çagan Irmak            1
# Ömer Faruk Sorak       1
# Length: 548, dtype: int64

# %% [markdown]
# we employ the size() method on the resulting GroupBy object, which computes
# the size (count) of each group. This translates into the number of movies directed by
# each individual.

# %% [markdown]
# ## Built-in Aggregation Methods

# %% [markdown]
# ### Statistical Calculations

# %%
grouped_data = df.groupby('Genre')

average_rating_by_genre = grouped_data['IMDB_Rating'].mean()
average_rating_by_genre
# Out:
# Genre
# Action       7.949419
# Adventure    7.937500
# Animation    7.930488
# Biography    7.938636
# Comedy       7.901290
# Crime        8.016822
# Drama        7.957439
# Family       7.800000
# Fantasy      8.000000
# Film-Noir    7.966667
# Horror       7.909091
# Mystery      7.975000
# Thriller     7.800000
# Western      8.350000
# Name: IMDB_Rating, dtype: float64

# %%
total_gross_by_genre = grouped_data['Gross'].sum()
total_gross_by_genre
# Out:
# Genre
# Action      32632261314.00
# Adventure    9496922464.00
# Animation   14631473048.00
# Biography    8276357606.00
# Comedy      15663868165.00
# Crime        8452631908.00
# Drama       35409974041.00
# Family        439110554.00
# Fantasy       782726696.00
# Film-Noir     125910543.00
# Horror       1034649238.00
# Mystery      1256417015.00
# Thriller       17550741.00
# Western        58221508.00
# Name: Gross, dtype: float64

# %%
lowest_rating_by_genre = grouped_data['IMDB_Rating'].min()
lowest_rating_by_genre
# Out:
# Genre
# Action      7.60
# Adventure   7.60
# Animation   7.60
# Biography   7.60
# Comedy      7.60
# Crime       7.60
# Drama       7.60
# Family      7.80
# Fantasy     7.90
# Film-Noir   7.80
# Horror      7.60
# Mystery     7.60
# Thriller    7.80
# Western     7.80
# Name: IMDB_Rating, dtype: float64

# %%
highest_votes_by_genre = grouped_data['No_of_Votes'].max()
highest_votes_by_genre
# Out:
# Genre
# Action       2303232
# Adventure    1512360
# Animation     999790
# Biography    1213505
# Comedy        939631
# Crime        1826188
# Drama        2343110
# Family        372490
# Fantasy        88794
# Film-Noir     158731
# Horror        787806
# Mystery      1129894
# Thriller       27733
# Western       688390
# Name: No_of_Votes, dtype: int64

# %%
valid_ratings_count_by_genre = grouped_data['IMDB_Rating'].count()
valid_ratings_count_by_genre
# Out:
# Genre
# Action       172
# Adventure     72
# Animation     82
# Biography     88
# Comedy       155
# Crime        107
# Drama        289
# Family         2
# Fantasy        2
# Film-Noir      3
# Horror        11
# Mystery       12
# Thriller       1
# Western        4
# Name: IMDB_Rating, dtype: int64

# %%
grouped_data = df.groupby('Released_Year')

# %%
median_rating_by_year = grouped_data['IMDB_Rating'].median()
median_rating_by_year
# Out:
# Released_Year
# 1920   8.10
# 1921   8.30
# 1922   7.90
# 1924   8.20
# 1925   8.10
#        ...
# 2017   7.80
# 2018   8.00
# 2019   7.90
# 2020   8.00
# PG     7.60
# Name: IMDB_Rating, Length: 100, dtype: float64

# %%
grouped_data = df.groupby('Genre')

# %%
std_deviation_by_genre = grouped_data['IMDB_Rating'].std()
std_deviation_by_genre
# Out:
# Genre
# Action      0.30
# Adventure   0.23
# Animation   0.25
# Biography   0.27
# Comedy      0.23
# Crime       0.34
# Drama       0.27
# Family      0.00
# Fantasy     0.14
# Film-Noir   0.15
# Horror      0.31
# Mystery     0.31
# Thriller     NaN
# Western     0.42
# Name: IMDB_Rating, dtype: float64

# %%
type(grouped_data)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
grouped_data.get_group('Thriller')
# Out:
#         Series_Title Released_Year  Runtime     Genre  IMDB_Rating  \
# 700  Wait Until Dark          1967      108  Thriller         7.80
#
#           Director           Star1  No_of_Votes       Gross  Metascore
# 700  Terence Young  Audrey Hepburn        27733 17550741.00      81.00

# %%
var_by_genre = grouped_data['IMDB_Rating'].var()
var_by_genre
# Out:
# Genre
# Action      0.09
# Adventure   0.05
# Animation   0.06
# Biography   0.07
# Comedy      0.05
# Crime       0.11
# Drama       0.07
# Family      0.00
# Fantasy     0.02
# Film-Noir   0.02
# Horror      0.10
# Mystery     0.10
# Thriller     NaN
# Western     0.18
# Name: IMDB_Rating, dtype: float64

# %% [markdown]
# ## Applying Different Functions to DataFrame Columns

# %%
result = df.agg({
    'IMDB_Rating': 'mean',
    'No_of_Votes': 'sum'
})

result
# Out:
# IMDB_Rating           7.95
# No_of_Votes   273692911.00
# dtype: float64

# %%
result = df.agg({'Gross': 'max', 'Metascore': 'min'})
result
# Out:
# Gross       936662225.00
# Metascore          28.00
# dtype: float64

# %% [markdown]
# ## Grouping DataFrame with Index Levels and Columns

# %%
grouped = df.groupby(['Genre', 'Released_Year']).agg({'IMDB_Rating': 'mean', 'No_of_Votes': 'sum'})
grouped
# Out:
#                         IMDB_Rating  No_of_Votes
# Genre    Released_Year
# Action   1924                  8.20        41985
#          1926                  8.10        81156
#          1932                  7.80        25312
#          1938                  7.90        47175
#          1948                  7.80        65162
# ...                             ...          ...
# Thriller 1967                  7.80        27733
# Western  1965                  8.30       232772
#          1966                  8.80       688390
#          1968                  8.50       302844
#          1976                  7.80        65659
#
# [434 rows x 2 columns]

# %% [markdown]
# ## Aggregation with User-defined Functions

# %%
df.head()
# Out:
#                Series_Title Released_Year  Runtime   Genre  IMDB_Rating  \
# 0  The Shawshank Redemption          1994      142   Drama         9.30
# 1             The Godfather          1972      175   Crime         9.20
# 2           The Dark Knight          2008      152  Action         9.00
# 3    The Godfather: Part II          1974      202   Crime         9.00
# 4              12 Angry Men          1957       96   Crime         9.00
#
#                Director           Star1  No_of_Votes        Gross  Metascore
# 0        Frank Darabont     Tim Robbins      2343110  28341469.00      80.00
# 1  Francis Ford Coppola   Marlon Brando      1620367 134966411.00     100.00
# 2     Christopher Nolan  Christian Bale      2303232 534858444.00      84.00
# 3  Francis Ford Coppola       Al Pacino      1129952  57300000.00      90.00
# 4          Sidney Lumet     Henry Fonda       689845   4360000.00      96.00

# %%
def custom_aggregation(group):
    high_rated = sum(group['IMDB_Rating'] > 8.0)
    low_rated = sum(group['IMDB_Rating'] <= 8.0)
    return pd.Series({'High_Rated': high_rated, 'Low_Rated': low_rated})

# %%
grouped_data = df.groupby('Genre').apply(custom_aggregation)
grouped_data
# Out:
# C:\Users\ZhangZhihui\AppData\Local\Temp\ipykernel_1072\2268400246.py:1: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   grouped_data = df.groupby('Genre').apply(custom_aggregation)
#            High_Rated  Low_Rated
# Genre
# Action             52        120
# Adventure          23         49
# Animation          25         57
# Biography          27         61
# Comedy             39        116
# Crime              42         65
# Drama             101        188
# Family              0          2
# Fantasy             1          1
# Film-Noir           1          2
# Horror              3          8
# Mystery             5          7
# Thriller            0          1
# Western             3          1

# %%
grouped_data = df.groupby('Genre', include_groups=False).apply(custom_aggregation)
grouped_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 grouped_data = df.groupby('Genre', include_groups=False).apply(custom_aggregation)
#       2 grouped_data
#
# TypeError: DataFrame.groupby() got an unexpected keyword argument 'include_groups'

# %%
grouped_data = (
    df[['Genre', 'IMDB_Rating']]
        .groupby('Genre')
        .apply(custom_aggregation)
)

grouped_data
# Out:
# C:\Users\ZhangZhihui\AppData\Local\Temp\ipykernel_1072\2791555089.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(custom_aggregation)
#            High_Rated  Low_Rated
# Genre
# Action             52        120
# Adventure          23         49
# Animation          25         57
# Biography          27         61
# Comedy             39        116
# Crime              42         65
# Drama             101        188
# Family              0          2
# Fantasy             1          1
# Film-Noir           1          2
# Horror              3          8
# Mystery             5          7
# Thriller            0          1
# Western             3          1

# %%
def custom_aggregation(series):
    high_rated = (series > 8.0).sum()
    low_rated = (series <= 8.0).sum()
    return pd.Series({'High_Rated': high_rated, 'Low_Rated': low_rated})

grouped_data = df.groupby('Genre')['IMDB_Rating'].apply(custom_aggregation)

grouped_data
# Out:
# Genre
# Action     High_Rated     52
#            Low_Rated     120
# Adventure  High_Rated     23
#            Low_Rated      49
# Animation  High_Rated     25
#            Low_Rated      57
# Biography  High_Rated     27
#            Low_Rated      61
# Comedy     High_Rated     39
#            Low_Rated     116
# Crime      High_Rated     42
#            Low_Rated      65
# Drama      High_Rated    101
#            Low_Rated     188
# Family     High_Rated      0
#            Low_Rated       2
# Fantasy    High_Rated      1
#            Low_Rated       1
# Film-Noir  High_Rated      1
#            Low_Rated       2
# Horror     High_Rated      3
#            Low_Rated       8
# Mystery    High_Rated      5
#            Low_Rated       7
# Thriller   High_Rated      0
#            Low_Rated       1
# Western    High_Rated      3
#            Low_Rated       1
# Name: IMDB_Rating, dtype: int64

# %%
pd.__version__
# Out:
# '2.3.1'

# %%
grouped_data = (
    df.groupby('Genre')
      .apply(custom_aggregation, include_groups=False)
)

grouped_data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 3
#       1 grouped_data = (
#       2     df.groupby('Genre')
# ----> 3       .apply(custom_aggregation, include_groups=False)
#       4 )
#       6 grouped_data
#
# File D:\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1820, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1817     f = func
#    1819 if not include_groups:
# -> 1820     return self._python_apply_general(f, self._obj_with_exclusions)
#    1822 # ignore SettingWithCopy here in case the user mutates
#    1823 with option_context("mode.chained_assignment", None):
#
# File D:\Python313\Lib\site-packages\pandas\core\groupby\groupby.py:1886, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1851 @final
#    1852 def _python_apply_general(
#    1853     self,
#    (...)   1858     is_agg: bool = False,
#    1859 ) -> NDFrameT:
#    1860     """
#    1861     Apply function f in python space
#    1862
#    (...)   1884         data after applying f
#    1885     """
# -> 1886     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1887     if not_indexed_same is None:
#    1888         not_indexed_same = mutated
#
# File D:\Python313\Lib\site-packages\pandas\core\groupby\ops.py:919, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     917 # group might be modified
#     918 group_axes = group.axes
# --> 919 res = f(group)
#     920 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     921     mutated = True
#
# Cell In[35], line 2, in custom_aggregation(series)
#       1 def custom_aggregation(series):
# ----> 2     high_rated = (series > 8.0).sum()
#       3     low_rated = (series <= 8.0).sum()
#       4     return pd.Series({'High_Rated': high_rated, 'Low_Rated': low_rated})
#
# File D:\Python313\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File D:\Python313\Lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File D:\Python313\Lib\site-packages\pandas\core\frame.py:7907, in DataFrame._cmp_method(self, other, op)
#    7904 self, other = self._align_for_op(other, axis, flex=False, level=None)
#    7906 # See GH#4537 for discussion of scalar op behavior
# -> 7907 new_data = self._dispatch_frame_op(other, op, axis=axis)
#    7908 return self._construct_result(new_data)
#
# File D:\Python313\Lib\site-packages\pandas\core\frame.py:7952, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    7949 right = lib.item_from_zerodim(right)
#    7950 if not is_list_like(right):
#    7951     # i.e. scalar, faster than checking np.ndim(right) == 0
# -> 7952     bm = self._mgr.apply(array_op, right=right)
#    7953     return self._constructor_from_mgr(bm, axes=bm.axes)
#    7955 elif isinstance(right, DataFrame):
#
# File D:\Python313\Lib\site-packages\pandas\core\internals\managers.py:361, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     358             kwargs[k] = obj[b.mgr_locs.indexer]
#     360 if callable(f):
# --> 361     applied = b.apply(f, **kwargs)
#     362 else:
#     363     applied = getattr(b, f)(**kwargs)
#
# File D:\Python313\Lib\site-packages\pandas\core\internals\blocks.py:395, in Block.apply(self, func, **kwargs)
#     389 @final
#     390 def apply(self, func, **kwargs) -> list[Block]:
#     391     """
#     392     apply the function to my values; return a block if we are not
#     393     one
#     394     """
# --> 395     result = func(self.values, **kwargs)
#     397     result = maybe_coerce_values(result)
#     398     return self._split_op_result(result)
#
# File D:\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:344, in comparison_op(left, right, op)
#     341     return invalid_comparison(lvalues, rvalues, op)
#     343 elif lvalues.dtype == object or isinstance(rvalues, str):
# --> 344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
#     347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#
# File D:\Python313\Lib\site-packages\pandas\core\ops\array_ops.py:129, in comp_method_OBJECT_ARRAY(op, x, y)
#     127     result = libops.vec_compare(x.ravel(), y.ravel(), op)
#     128 else:
# --> 129     result = libops.scalar_compare(x.ravel(), y, op)
#     130 return result.reshape(x.shape)
#
# File pandas/_libs/ops.pyx:107, in pandas._libs.ops.scalar_compare()
#
# TypeError: '>' not supported between instances of 'str' and 'float'

# %%
def custom_aggregation(group):
    high_rated = (group['IMDB_Rating'] > 8.0).sum()
    low_rated = (group['IMDB_Rating'] <= 8.0).sum()
    return pd.Series({'High_Rated': high_rated, 'Low_Rated': low_rated})

grouped_data = (
    df.groupby('Genre')
      .apply(custom_aggregation, include_groups=False)
)

# %%
grouped_data
# Out:
#            High_Rated  Low_Rated
# Genre
# Action             52        120
# Adventure          23         49
# Animation          25         57
# Biography          27         61
# Comedy             39        116
# Crime              42         65
# Drama             101        188
# Family              0          2
# Fantasy             1          1
# Film-Noir           1          2
# Horror              3          8
# Mystery             5          7
# Thriller            0          1
# Western             3          1

# %%
def most_prolific_director(group):
    director_count = group.shape[0]  # Count of movies directed by the director
    return pd.Series({'Total_Movies': director_count})

# %%
# Grouping data by Director and applying the UDF
grouped_by_director = df.groupby('Director')
prolific_director_stats = grouped_by_director.apply(most_prolific_director)
# Out:
# C:\Users\ZhangZhihui\AppData\Local\Temp\ipykernel_1072\2833821754.py:3: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   prolific_director_stats = grouped_by_director.apply(most_prolific_director)

# %%
# Grouping data by Director and applying the UDF
grouped_by_director = df.groupby('Director')
prolific_director_stats = grouped_by_director.apply(most_prolific_director, include_groups=False)

# %%
# Find the director with the most movies
most_prolific = prolific_director_stats['Total_Movies'].idxmax()
print(f"The most prolific director is '{most_prolific}' with {prolific_director_stats['Total_Movies'].max()} movies.")
# Out:
# The most prolific director is 'Alfred Hitchcock' with 14 movies.

# %% [markdown]
# ## Iterating Through Groups

# %%
def group_by_decade(year):
    return f"{(int(year) // 10) * 10}s"

# %%
grouped_by_decade = df.groupby(df['Released_Year'].apply(group_by_decade))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 grouped_by_decade = df.groupby(df['Released_Year'].apply(group_by_decade))
#
# File D:\Python313\Lib\site-packages\pandas\core\series.py:4935, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4800 def apply(
#    4801     self,
#    4802     func: AggFuncType,
#    (...)   4807     **kwargs,
#    4808 ) -> DataFrame | Series:
#    4809     """
#    4810     Invoke function on values of Series.
#    4811
#    (...)   4926     dtype: float64
#    4927     """
#    4928     return SeriesApply(
#    4929         self,
#    4930         func,
#    4931         convert_dtype=convert_dtype,
#    4932         by_row=by_row,
#    4933         args=args,
#    4934         kwargs=kwargs,
# -> 4935     ).apply()
#
# File D:\Python313\Lib\site-packages\pandas\core\apply.py:1422, in SeriesApply.apply(self)
#    1419     return self.apply_compat()
#    1421 # self.func is Callable
# -> 1422 return self.apply_standard()
#
# File D:\Python313\Lib\site-packages\pandas\core\apply.py:1502, in SeriesApply.apply_standard(self)
#    1496 # row-wise access
#    1497 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1498 # we need to give `na_action="ignore"` for categorical data.
#    1499 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1500 #  Categorical (GH51645).
#    1501 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1502 mapped = obj._map_values(
#    1503     mapper=curried, na_action=action, convert=self.convert_dtype
#    1504 )
#    1506 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1507     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1508     #  See also GH#25959 regarding EA support
#    1509     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File D:\Python313\Lib\site-packages\pandas\core\base.py:925, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     922 if isinstance(arr, ExtensionArray):
#     923     return arr.map(mapper, na_action=na_action)
# --> 925 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File D:\Python313\Lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File pandas/_libs/lib.pyx:2999, in pandas._libs.lib.map_infer()
#
# Cell In[45], line 2, in group_by_decade(year)
#       1 def group_by_decade(year):
# ----> 2     return f"{(int(year) // 10) * 10}s"
#
# ValueError: invalid literal for int() with base 10: 'PG'

# %%
df['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943', 'PG'], dtype=object)

# %%
delete_row_index = df[df['Released_Year'] == 'PG'].index
df.drop(delete_row_index, inplace=True)

# %%
df['Released_Year'].unique()
# Out:
# array(['1994', '1972', '2008', '1974', '1957', '2003', '1993', '2010',
#        '1999', '2001', '1966', '2002', '1990', '1980', '1975', '2020',
#        '2019', '2014', '1998', '1997', '1995', '1991', '1977', '1962',
#        '1954', '1946', '2011', '2006', '2000', '1988', '1985', '1968',
#        '1960', '1942', '1936', '1931', '2018', '2017', '2016', '2012',
#        '2009', '2007', '1984', '1981', '1979', '1971', '1963', '1964',
#        '1950', '1940', '2013', '2005', '2004', '1992', '1987', '1986',
#        '1983', '1976', '1973', '1965', '1959', '1958', '1952', '1948',
#        '1944', '1941', '1927', '1921', '2015', '1996', '1989', '1978',
#        '1961', '1955', '1953', '1925', '1924', '1982', '1967', '1951',
#        '1949', '1939', '1937', '1934', '1928', '1926', '1920', '1970',
#        '1969', '1956', '1947', '1945', '1930', '1938', '1935', '1933',
#        '1932', '1922', '1943'], dtype=object)

# %%
grouped_by_decade = df.groupby(df['Released_Year'].apply(group_by_decade))

# %%
# Calculate average rating for each decade
average_rating_by_decade = {}
for decade, group in grouped_by_decade:
    average_rating = group['IMDB_Rating'].mean()
    average_rating_by_decade[decade] = average_rating

for decade, avg_rating in average_rating_by_decade.items():
    print(f'Decade: {decade}, Average Rating: {avg_rating:.2f}')
# Out:
# Decade: 1920s, Average Rating: 8.13
# Decade: 1930s, Average Rating: 7.97
# Decade: 1940s, Average Rating: 8.03
# Decade: 1950s, Average Rating: 8.06
# Decade: 1960s, Average Rating: 7.97
# Decade: 1970s, Average Rating: 7.97
# Decade: 1980s, Average Rating: 7.95
# Decade: 1990s, Average Rating: 7.96
# Decade: 2000s, Average Rating: 7.90
# Decade: 2010s, Average Rating: 7.92
# Decade: 2020s, Average Rating: 8.13

# %%
grouped_by_genre = df.groupby('Genre')

total_votes_by_genre = {}
for genre, group in grouped_by_genre:
    total_votes = group['No_of_Votes'].sum()
    total_votes_by_genre[genre] = total_votes

for genre, total_votes in total_votes_by_genre.items():
    print(f'Genre: {genre}, Total Votes: {total_votes}')
# Out:
# Genre: Action, Total Votes: 72282412
# Genre: Adventure, Total Votes: 22306966
# Genre: Animation, Total Votes: 21978630
# Genre: Biography, Total Votes: 24006844
# Genre: Comedy, Total Votes: 27620327
# Genre: Crime, Total Votes: 33533615
# Genre: Drama, Total Votes: 61367304
# Genre: Family, Total Votes: 551221
# Genre: Fantasy, Total Votes: 146222
# Genre: Film-Noir, Total Votes: 367215
# Genre: Horror, Total Votes: 3742556
# Genre: Mystery, Total Votes: 4203004
# Genre: Thriller, Total Votes: 27733
# Genre: Western, Total Votes: 1289665

# %% [markdown]
# ## Discretization and Binning

# %% [markdown]
# Syntax
#
# pd.cut(data_series, bins, labels=labels, right=False)

# %%
rating_bins = [0, 6.5, 7.5, 8.5, 10]
rating_labels = ['Low', 'Average', 'Good', 'Excellent']

# %%
# Discretize IMDB ratings
df['Rating_Category'] = pd.cut(df['IMDB_Rating'], bins=rating_bins, labels=rating_labels, right=False)

df[['Series_Title', 'IMDB_Rating', 'Rating_Category']]
# Out:
#                  Series_Title  IMDB_Rating Rating_Category
# 0    The Shawshank Redemption         9.30       Excellent
# 1               The Godfather         9.20       Excellent
# 2             The Dark Knight         9.00       Excellent
# 3      The Godfather: Part II         9.00       Excellent
# 4                12 Angry Men         9.00       Excellent
# ..                        ...          ...             ...
# 995    Breakfast at Tiffany's         7.60            Good
# 996                     Giant         7.60            Good
# 997     From Here to Eternity         7.60            Good
# 998                  Lifeboat         7.60            Good
# 999              The 39 Steps         7.60            Good
#
# [999 rows x 3 columns]
